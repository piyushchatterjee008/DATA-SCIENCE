# %% [markdown]
# # Matplotlib is a 2d plotting library used for data visualization in python.

# %%
#A PIC CAN SAY 1000 words

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(matplotlib.__version__)
# Out:
# 3.3.4

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
#color
plt.plot(x,y,color='green')

# %%
#linewidhth
plt.plot(x,y,color='blue',linewidth=3)

# %%
#linestyle

plt.plot(x,y,color='green',linewidth=3,linestyle='dashed')

# %%
#levels

plt.xlabel='days'
plt.ylabel='temprature'
plt.title='Raipur weather'
plt.plot(x,y,color='green',linewidth=3,linestyle='dotted')
