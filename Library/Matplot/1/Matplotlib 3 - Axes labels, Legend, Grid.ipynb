# %%
#Matplotlib Tutorial 3 - Axes labels, Legend, Grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avg")

# %%
#Axes labels and chart title
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avg")
plt.xlabel("day")
plt.ylabel("temp")
plt.title("weather")
# Out:
# Text(0.5, 1.0, 'weather')

# %% [markdown]
# # Legend

# %%
# Show legend
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(loc='best')#by default

# %%
# Legend at different location with shadow enabled
 
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.legend(loc="upper right",shadow=True)

# %%
# Legend at different location with fontsize set to large
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.legend(loc="upper left",shadow=True,fontsize="large")

# %% [markdown]
# # Grid

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.legend(loc="upper left",shadow=True,fontsize="large")
plt.grid()
