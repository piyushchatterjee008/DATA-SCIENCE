# %% [markdown]
# # Different Ways Of Creating DataFrame

# %%
# Create dataframe using read_csv() method 

import pandas as pd

df= pd.read_csv('nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 12F0-0949
#
#  Directory of C:\Users\PIYUSH\Desktop\j- python\Untitled Folder
#
# 09/01/2021  02:41 AM    <DIR>          .
# 09/01/2021  02:41 AM    <DIR>          ..
# 09/01/2021  02:40 AM    <DIR>          .ipynb_checkpoints
# 08/31/2021  02:00 AM            56,243 juputer1.ipynb
# 09/01/2021  12:22 AM            43,716 Numpy 1.ipynb
# 09/01/2021  12:22 AM            31,266 Numpy intro.ipynb
# 09/01/2021  12:50 AM             1,368 nyc_weather.csv
# 09/01/2021  02:40 AM            78,158 Pandas 1 Dataframe Basics.ipynb
# 09/01/2021  02:40 AM               756 Pandas 2 Different Ways Of Creating DataFrame.ipynb
# 09/01/2021  02:41 AM             8,223 weather_data.xlsx
#                7 File(s)        219,730 bytes
#                3 Dir(s)  45,605,838,848 bytes free

# %%
#Create dataframe using read_excel() method

exl=pd.read_excel('weather_data.xlsx')
exl
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
#create dataframe using python dictionary DataFrame() method

weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
#Create dataframe using tuples list DataFrame() method

weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
#Create dataframe using the list of dictionary DataFrame() method

weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# # Read Write Excel CSV File

# %%
import pandas as pd
import requests

url = 'https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv'
res = requests.get(url, allow_redirects=True)
with open('stock_data.csv','wb') as file:
    file.write(res.content)

# %%
df = pd.read_csv('stock_data.csv', )
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#Skip rows in dataframe using "skiprows" if youextra header 
df = pd.read_csv('stock_data.csv', skiprows= 2)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
# telling my header at row 1
df = pd.read_csv('stock_data.csv', header= 1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
# Import data from CSV file with "null header"
df = pd.read_csv('stock_data.csv', header= None )
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
# give header name manually 

df = pd.read_csv("stock_data.csv", header=None, names = ["ticker","eps","revenue","people"])
df
# Out:
#                 ticker      eps revenue         people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
#to show specific now of rows, Read limited data from CSV file

df = pd.read_csv("stock_data.csv",  nrows=2)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
#Clean up messy data from file "not available" and "n.a." replace with "na_values"

df= pd.read_csv("stock_data.csv", na_values=(['not available','n.a.']))
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
#dealing (-1) in revenue  Supply dictionary for replace with "na_values"
import pandas as pd

df = pd.read_csv("stock_data.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['n.a.']
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
#Write dataframe into "csv" file with "to_csv() method
import pandas as pd
df1=df.to_csv('new.csv')
df1

# %%
##Write dataframe into "csv" file with "to_csv() method, with out index

df.to_csv("new.csv", index=False)

# %%
#Write dataframe into "csv" file with "to_csv() method, particular columns

df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("new.csv", columns=['tickers','people'])

# %%
#Write dataframe into "csv" file with "to_csv() method, wiith no header
df.to_csv("new.csv", header=False)

# %%
#Read excel file using read_excel() method 
df = pd.read_excel("stock_data.xlsx","Sheet1")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#Converters argument in read_excel() method 

def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Sam Walton'
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return 50
    return cell

def convert_eps(cell):
    if cell=="not available":
        return 8
    return cell

df = pd.read_excel("stock_data.xlsx","Sheet1", converters={
    'price': convert_price_cell,
    'people': convert_people_cell,
    'eps':convert_eps
})
df
# Out:
#   tickers    eps  revenue  price         people
# 0   GOOGL  27.82       87    845     larry page
# 1     WMT   4.61      484     65     Sam Walton
# 2    MSFT  -1.00       85     64     bill gates
# 3    RIL    8.00       50   1023  mukesh ambani
# 4    TATA   5.60       -1     50     ratan tata

# %%
#Write dataframe into "excel" file with "to_excel() method"

# %%
df.to_excel('newexcel.xlsx',sheet_name="millionner")

# %%
df.to_excel("newexcel.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)
#give 2 gaps in rows and 1 gap in column

# %% [markdown]
# # Write two dataframes to two separate sheets in excel

# %%
#Use ExcelWritter() class 

df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

with pd.ExcelWriter('2 sheet stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")
